# %%
# !pip install python-dotenv

# %%
pip install google-generativeai

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define your project path inside Drive
project_path = "/content/drive/MyDrive/my-colab-project"

# Create the folder if it doesn't exist
import os
os.makedirs(project_path, exist_ok=True)

# Move into the folder
# %cd $project_path/advanced-prompt
# Out:
# /content/drive/MyDrive/my-colab-project/advanced-prompt

# %%
from dotenv import load_dotenv
import os

# Load environment variables from the .env file
load_dotenv()

# Access your API key from the environment variables
gemini_api_key = os.getenv("GEMINI_API_KEY")

# Print to check (you can remove this after confirming)
print(gemini_api_key)
# Out:
# AIzaSyAvv40a6q9PsGINzoCizCvypQ3hFVsI-lA

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAvv40a6q9PsGINzoCizCvypQ3hFVsI-lA")

model = genai.GenerativeModel('gemini-2.0-flash')

# %%
response = model.generate_content(
  """Let's solve a math problem step by step:\nWhat is 37 multiplied by 24?

  (e.g., no *, **, or other formatting symbols) """
)
print(response.text)
# Out:
# Okay, let's multiply 37 by 24 step by step.
#
# 1. **Multiply 37 by 4 (the ones digit of 24):**
#    7 multiplied by 4 is 28. Write down 8 and carry-over 2.
#    3 multiplied by 4 is 12. Add the carry-over 2 to get 14.
#    So, 37 multiplied by 4 is 148.
#
# 2. **Multiply 37 by 20 (the tens digit of 24, which is 2):**
#    7 multiplied by 2 is 14. Write down 0 as placeholder, write 4 and carry-over 1.
#    3 multiplied by 2 is 6. Add the carry-over 1 to get 7.
#    So, 37 multiplied by 20 is 740.
#
# 3. **Add the results from step 1 and step 2:**
#    148 + 740 = 888
#
# Therefore, 37 multiplied by 24 is 888.

# %%
# Step 2: Define Input (example support email)
email = """
Hi team, I've been having constant issues with your app crashing every time I try to upload a file.
I’ve reported this before, but still no fix. It's extremely frustrating and affecting my work.
"""

# Step 3: Build Prompt
prompt = f"""
You are a professional customer support analyst.

TASK:
1. Summarize the user's email in clear bullet points.
2. Classify the sentiment (Positive, Neutral, Negative) with explanation.
3. Suggest a professional, empathetic response addressing the issue.

EMAIL:
\"\"\"{email}\"\"\"
"""

# Step 4: Get Response
response = model.generate_content(prompt)
print(response.text)
# Out:
# Okay, I'm ready to analyze the email. Here's my breakdown:
#
# **1. Summary of User's Email:**
#
# *   The user is experiencing frequent app crashes when uploading files.
# *   The user has reported the issue previously.
# *   The issue remains unresolved.
# *   The user is frustrated because the problem is disrupting their work.
#
# **2. Sentiment Classification:**
#
# *   **Sentiment:** Negative
# *   **Explanation:** The email expresses frustration ("extremely frustrating"), indicates a recurring problem ("constant issues," "reported this before, but still no fix"), and highlights the negative impact on the user's productivity ("affecting my work").
#
# **3. Suggested Response:**
#
# Subject: Regarding App Crashing Issues When Uploading Files
#
# Dear [User Name],
#
# ...

# %%
import json

# Replace with the actual file name
filename = "prompt_usecase.ipynb"

# Load the notebook
with open("/filename", "r", encoding="utf-8") as f:
    nb = json.load(f)

# Remove the problematic widgets metadata
if "widgets" in nb.get("metadata", {}):
    del nb["metadata"]["widgets"]
    print("Deleted 'metadata.widgets'.")
else:
    print("No widgets metadata found.")

# Save the cleaned notebook
with open(filename, "w", encoding="utf-8") as f:
    json.dump(nb, f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-27d3746fb23c> in <cell line: 0>()
#       5
#       6 # Load the notebook
# ----> 7 with open("/Task2/filename", "r", encoding="utf-8") as f:
#       8     nb = json.load(f)
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Task2/filename'
